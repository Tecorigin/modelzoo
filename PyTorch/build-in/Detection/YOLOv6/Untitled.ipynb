# %%
from ultralytics import YOLO

# ① 指定结构配置
model = YOLO('yolov6n.yaml')    
# ② 加载 Meituan 官方权重
model.load('yolov6n.pt')        
# ③ 导出 ONNX
model.export(format='onnx', imgsz=640, opset=13, simplify=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[4], line 6
#       4 model = YOLO('yolov6n.yaml')
#       5 # ② 加载 Meituan 官方权重
# ----> 6 model.load('yolov6n.pt')
#       7 # ③ 导出 ONNX
#       8 model.export(format='onnx', imgsz=640, opset=13, simplify=True)
#
# File ~/miniconda3/envs/yolo/lib/python3.10/site-packages/ultralytics/engine/model.py:387, in Model.load(self, weights)
#     385     self.overrides["pretrained"] = weights  # remember the weights for DDP training
#     386     weights, self.ckpt = attempt_load_one_weight(weights)
# --> 387 self.model.load(weights)
#     388 return self
#
# File ~/miniconda3/envs/yolo/lib/python3.10/site-packages/ultralytics/nn/tasks.py:320, in BaseModel.load(self, weights, verbose)
#     318 if first_conv not in updated_csd and first_conv in state_dict:
#     319     c1, c2, h, w = state_dict[first_conv].shape
# --> 320     cc1, cc2, ch, cw = csd[first_conv].shape
#     321     if ch == h and cw == w:
#     322         c1, c2 = min(c1, cc1), min(c2, cc2)
#
# KeyError: 'model.0.conv.weight'
